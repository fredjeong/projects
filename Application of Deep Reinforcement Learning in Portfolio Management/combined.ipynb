# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### PPO
#
# 들어가야 할 것: `value_losses`, `actor_losses`, `portfolio_values`

# %%
ppo_policy_losses = pd.read_csv("./ppo/records/policy_losses.csv", header=None)
ppo_value_losses = pd.read_csv("./ppo/records/value_losses.csv", header=None)

# %%
plt.plot(ppo_policy_losses)

# %%
plt.plot(ppo_value_losses)

# %%
for i in range(20):
    globals()[f'ppo_benchmark_{i}'] = pd.read_csv(f"./ppo/records/benchmark_{i}.csv", header=None)
    globals()[f'ppo_portfolio_values_{i}'] = pd.read_csv(f"./ppo/records/portfolio_values_{i}.csv", header=None)
    plt.plot(globals()[f'ppo_benchmark_{i}'], label='Benchmark')
    plt.plot(globals()[f'ppo_portfolio_values_{i}'], label='PPO')
    plt.legend()
    plt.show()

# %% [markdown]
# ### DDPG
#
# train에서 들어갈 것: actor_losses, critic_losses
# test에서 들어갈 것: portfolio_values

# %%
ddpg_actor_losses = pd.read_csv("./ddpg/records/actor_losses.csv", header=None)
ddpg_critic_losses = pd.read_csv("./ddpg/records/critic_losses.csv", header=None)

# %%
plt.plot(ddpg_actor_losses)

# %%
plt.plot(ddpg_critic_losses)

# %%
ddpg_portfolio_values_0
# Out:
#                 0
# 0     1000.000000
# 1     1004.641178
# 2     1004.922573
# 3     1007.961983
# 4     1010.634448
# ...           ...
# 1824   514.991219
# 1825   509.479747
# 1826   506.623521
# 1827   505.350499
# 1828   500.913805
#
# [1829 rows x 1 columns]

# %%
ddpg_benchmark_0
# Out:
#                 0
# 0     1004.125300
# 1     1005.225112
# 2     1005.447313
# 3     1011.652055
# 4     1010.537246
# ...           ...
# 1824   510.780147
# 1825   508.039170
# 1826   506.725394
# 1827   501.208378
# 1828   500.234241
#
# [1829 rows x 1 columns]

# %%
plt.plot(ddpg_benchmark_0)
plt.plot(ddpg_portfolio_values_0)
plt.show()

# %%
for i in range(20):
    globals()[f'ddpg_benchmark_{i}'] = pd.read_csv(f"./ddpg/records/benchmark_{i}.csv", header=None)
    globals()[f'ddpg_portfolio_values_{i}'] = pd.read_csv(f"./ddpg/records/portfolio_values_{i}.csv", header=None)

# %%
for i in range(20):    
    plt.plot(globals()[f'ddpg_benchmark_{i}'], label='Benchmark')
    plt.plot(globals()[f'ddpg_portfolio_values_{i}'], label='DDPG')
    plt.legend()
    plt.show()

# %% [markdown]
# ### DQN
#
# train에서 들어갈 것: losses\
# test에서 들어갈 것: portfolio_value

# %%
dqn_losses = pd.read_csv("./dqn/records/losses.csv", header=None)

# %%
plt.plot(dqn_losses.index.values, dqn_losses)

# %%
for i in range(20):
    globals()[f'dqn_benchmark_{i}'] = pd.read_csv(f"./dqn/records/benchmark_{i}.csv", header=None)
    globals()[f'dqn_portfolio_values_{i}'] = pd.read_csv(f"./dqn/records/portfolio_values_{i}.csv", header=None)
    fig = plt.figure()
    plt.plot(globals()[f'dqn_benchmark_{i}'], label='Benchmark')
    plt.plot(globals()[f'dqn_portfolio_values_{i}'], label='DQN')
    plt.legend()
    plt.show()

# %% [markdown]
# ### A2C
#
# Train에서 들어갈 것: Actor_loss, Critic_loss\
# Test에서 들어갈 것: portfolio_values

# %%
a2c_actor_losses = pd.read_csv("./a2c/records/actor_losses.csv", header=None)
a2c_critic_losses = pd.read_csv("./a2c/records/critic_losses.csv", header=None)

# %%
for i in range(20):
    globals()[f'a2c_benchmark_{i}'] = pd.read_csv(f"./a2c/records/benchmark_{i}.csv", header=None)
    globals()[f'a2c_portfolio_values_{i}'] = pd.read_csv(f"./a2c/records/portfolio_values_{i}.csv", header=None)
    plt.plot(globals()[f'a2c_benchmark_{i}'], label='Benchmark')
    plt.plot(globals()[f'a2c_portfolio_values_{i}'], label='A2C')
    plt.legend()
    plt.show()

# %%
a2c_portfolio_values_19[930:940]
# Out:
#               0
# 930  953.627777
# 931  953.627777
# 932  953.627777
# 933  953.627777
# 934  751.743716
# 935  751.466522
# 936  751.723783
# 937  754.882239
# 938  755.192870
# 939  756.988281

# %%
plt.plot(a2c_actor_losses.index.values, a2c_actor_losses)

# %%
plt.plot(a2c_critic_losses.index.values, a2c_critic_losses)
