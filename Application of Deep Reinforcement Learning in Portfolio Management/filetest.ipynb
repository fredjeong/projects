# %%
import pickle
import time
import numpy as np
import argparse
import re
import pandas as pd

from environment import TradingEnv
from dqn import DQNAgent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 9
#       6 import pandas as pd
#       8 from environment import TradingEnv
# ----> 9 from dqn import DQNAgent
#
# File ~/Desktop/Project_new/dqn.py:4
#       2 import random
#       3 import numpy as np
# ----> 4 from model import mlp
#       7 class DQNAgent(object):
#       8     """ A simple Deep Q agent """
#
# File ~/Desktop/Project_new/model.py:1
# ----> 1 import tensorflow as tf
#       2 #from tf.keras.models import Sequential
#       3 #from tf.keras.layers import Dense
#       4 #from tf.keras.optimizers import Adam
#       7 def mlp(n_obs, n_action, n_hidden_layer=1, n_neuron_per_layer=32,
#       8         activation='relu', loss='mse'):
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ...
